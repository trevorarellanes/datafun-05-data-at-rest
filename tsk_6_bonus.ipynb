# %% [markdown]
# ## Trevor Arellanes
# ## Fundamentals of Data Analytics
# ## Task 6 - Bonus
# ## Domain - Golf

# %%
import pandas as pd # importing needed library

# %% [markdown]
# ## Importing Data Set to Analyze

# %%
golf_data = pd.read_csv("C:\\Users\\tarellanes\\Desktop\\OWGR_Ranking.csv") # import csv file from local file into pandas

golf_data.head() # large data file only looks at the first 6 rows to work with for this project
# Out:
#    Week  This_Week  Last_Week  End_2019            Name  Average_Points  \
# 0    11          1        1.0       2.0    Rory McIlroy            9.45
# 1    11          2        2.0       3.0        Jon Rahm            8.48
# 2    11          3        3.0       1.0   Brooks Koepka            7.73
# 3    11          4        4.0       4.0   Justin Thomas            7.41
# 4    11          5        5.0       5.0  Dustin Johnson            6.45
#
#    Total_Points  Events_Played_Divisor  Points_Lost_2020  Points_Gained_2020  \
# 0        444.03                     47            -85.08               61.59
# 1        407.03                     48            -64.65               75.22
# 2        347.81                     45            -89.28                9.48
# 3        340.92                     46            -69.27               77.52
# 4        270.86                     42            -69.22               49.30
#
#    Events_Played_Actual Pro/Am
# 0                    47    Pro
# ...

# %% [markdown]
# ## Practicing Changing Column Titles - No _

# %%
golf_data.columns=['Week', 'Current Week', 'Last Week', 'End 2019', 'Player', 'Average Points', 'Total Points', 'Events Played Divisor', 'Points Lost', 'Points Gained', 'Events Played', 'Skill'] # changing column names

# %%
golf_data.head() # cleaned up table
# Out:
#    Week  Current Week  Last Week  End 2019          Player  Average Points  \
# 0    11             1        1.0       2.0    Rory McIlroy            9.45
# 1    11             2        2.0       3.0        Jon Rahm            8.48
# 2    11             3        3.0       1.0   Brooks Koepka            7.73
# 3    11             4        4.0       4.0   Justin Thomas            7.41
# 4    11             5        5.0       5.0  Dustin Johnson            6.45
#
#    Total Points  Events Played Divisor  Points Lost  Points Gained  \
# 0        444.03                     47       -85.08          61.59
# 1        407.03                     48       -64.65          75.22
# 2        347.81                     45       -89.28           9.48
# 3        340.92                     46       -69.27          77.52
# 4        270.86                     42       -69.22          49.30
#
#    Events Played Skill
# 0             47   Pro
# 1             48   Pro
# 2             45   Pro
# ...

# %% [markdown]
# ## Removing Excessive Decimal Points

# %%
pd.set_option('display.precision', 2) # 2 decimal places

golf_data.describe() # shows general statistics for data set
# Out:
#          Week  Current Week  Last Week  End 2019  Average Points  \
# count  9000.0       9000.00    8995.00   8794.00        2.09e+03
# mean     11.0       1846.57    1844.89   1829.44        3.33e-01
# std       0.0        527.98     527.39    527.49        7.46e-01
# min      11.0          1.00       1.00      1.00        3.00e-04
# 25%      11.0       2089.00    2087.00   2074.00        3.00e-02
# 50%      11.0       2089.00    2087.00   2074.00        9.48e-02
# 75%      11.0       2089.00    2087.00   2074.00        2.89e-01
# max      11.0       2089.00    2087.00   2074.00        9.45e+00
#
#        Total Points  Events Played Divisor  Points Lost  Points Gained  \
# count       2088.00                9000.00      2068.00         649.00
# mean          15.62                  40.66        -3.23           8.88
# std           35.82                   2.44         7.33          13.70
# min            0.01                  40.00       -89.28           1.20
# ...

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# ## Creating Histogram of Data for Visualization

# %%
histogram = golf_data.hist()
